# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\435484\appdata\local\continuum\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Installing collected packages: tweepy
# Successfully installed tweepy-3.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# import tweepy
import tweepy as tw

# your Twitter API key and API secret
my_api_key = "YrT0xzNWJFUMMXIY3s2eY0Xpi"
my_api_secret = "AKKbyER77Ldx8T4oUuIasSHIgZOUzoIJcaUkoA9gjbJWzKswhH"

# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#covid19 -filter:retweets"

# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2020-09-16").items(50)

# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 50

# %%
import pandas as pd

# intialize the dataframe
tweets_df = pd.DataFrame()

# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
tweets_df.head()
# Out:
#                   user_name     user_location  \
# 0  Say no to the vaccine 🇦🇺  Tristan da Cunha
# 1               Rayeef khan         Bangalore
# 2               Tamer Yazar     Turkey-Israel
# 3                   Big Guy
# 4                Phil Xenos
#
#                                     user_description  user_verified  \
# 0  Immunity: Natural\nVaccination Status:  Uncomp...          False
# 1                                     Ya me Again:-!          False
# 2  Im Market Analyst, also Editor... working (fre...          False
# 3                                                             False
# 4  average class conscious worker , this gravedig...          False
#
#                  date                                               text  \
# 0 2021-06-27 22:17:59  Continued lockdowns are not about individuals ...
# 1 2021-06-27 22:17:59  Is this the new normal? Or is the normal alrea...
# 2 2021-06-27 22:17:42  The #Delta and #Kappa coronavirus #variants ha...
# 3 2021-06-27 22:17:37  Virtually Everyone who is contracting #COVID19...
# 4 2021-06-27 22:17:37  @BreakfastNews @LisaMillar could someone show ...
#
#                                             hashtags               source
# 0                                               None  Twitter for Android
# 1  [COVID19, OnlineClasses, MaskUp, coronavirus, ...  Twitter for Android
# 2                    [Delta, Kappa, variants, Italy]            TweetDeck
# 3                                          [COVID19]     Twitter for iPad
# 4                               [Australia, COVID19]  Twitter for Android
